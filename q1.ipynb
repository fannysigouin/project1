# %%
# Dependencies
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read in datasets and merge them into a single df
# Create empty df to store data
df = pd.DataFrame()
# Loop through years
for year in ['2018', '2020', '2022']:
    # Read in year data
    year_data = pd.read_csv(Path('resources', ('mci_' + year + '.csv')))
    # concatenate with general df
    df = pd.concat([df, year_data])
    # Log number of rows for this year and total in general df
    print(f"After reading in {len(year_data)} rows of data from year {year}, the total number of rows is: {len(df)}")
# Out:
# After reading in 37490 rows of data from year 2018, the total number of rows is: 37490
# After reading in 35065 rows of data from year 2020, the total number of rows is: 72555
# After reading in 40226 rows of data from year 2022, the total number of rows is: 112781

# %%
# Show how raw dataframe looks like
df.head()
# Out:
#       _id EVENT_UNIQUE_ID REPORT_DATE    OCC_DATE  REPORT_YEAR REPORT_MONTH  \
# 0  134022     GO-20181532  2018-01-01  2018-01-01         2018      January
# 1  134023     GO-20184352  2018-01-01  2018-01-01         2018      January
# 2  134024     GO-20184878  2018-01-01  2018-01-01         2018      January
# 3  134025     GO-20183609  2018-01-01  2018-01-01         2018      January
# 4  134026     GO-20184674  2018-01-01  2018-01-01         2018      January
#
#    REPORT_DAY  REPORT_DOY  REPORT_DOW  REPORT_HOUR  ...  \
# 0           1           1  Monday              4.0  ...
# 1           1           1  Monday             18.0  ...
# 2           1           1  Monday             21.0  ...
# 3           1           1  Monday             15.0  ...
# 4           1           1  Monday             20.0  ...
#
#                                        LOCATION_TYPE PREMISES_TYPE  UCR_CODE  \
# 0  Other Commercial / Corporate Places (For Profi...    Commercial      1430
# 1                   Apartment (Rooming House, Condo)     Apartment      1430
# 2                   Apartment (Rooming House, Condo)     Apartment      1420
# 3  Streets, Roads, Highways (Bicycle Path, Privat...       Outside      2130
# 4                                 Convenience Stores    Commercial      1610
#
#    UCR_EXT              OFFENCE  MCI_CATEGORY HOOD_158    NEIGHBOURHOOD_158  \
# 0      100              Assault       Assault      168  Downtown Yonge East
# 1      100              Assault       Assault      150    Fenside-Parkwoods
# 2      100  Assault With Weapon       Assault      106   Humewood-Cedarvale
# 3      210           Theft Over    Theft Over       95                Annex
# 4      210   Robbery - Business       Robbery      123           Cliffcrest
#
#   HOOD_140           NEIGHBOURHOOD_140
# 0       75  Church-Yonge Corridor (75)
# 1       45      Parkwoods-Donalda (45)
# 2      106    Humewood-Cedarvale (106)
# 3       95                  Annex (95)
# 4      123            Cliffcrest (123)
#
# [5 rows x 27 columns]

# %%
# Some offences were reported within the same day, some were reported in another day
different_dates = df[df['REPORT_DATE'] != df['OCC_DATE']]
print(different_dates)
# Out:
#           _id EVENT_UNIQUE_ID REPORT_DATE    OCC_DATE  REPORT_YEAR  \
# 97     134137     GO-20189063  2018-01-02  2018-01-01         2018
# 98     134139     GO-20185439  2018-01-02  2018-01-01         2018
# 104    134149     GO-20186854  2018-01-02  2018-01-01         2018
# 112    134159     GO-20187788  2018-01-02  2018-01-01         2018
# 114    134165     GO-20188891  2018-01-02  2018-01-01         2018
# ...       ...             ...         ...         ...          ...
# 40215  323286  GO-20222558042  2022-12-31  2022-12-29         2022
# 40217  323288  GO-20222563482  2022-12-31  2022-12-29         2022
# 40218  323289  GO-20222563482  2022-12-31  2022-12-29         2022
# 40221  323292  GO-20222554300  2022-12-31  2022-12-22         2022
# 40223  323294  GO-20222559486  2022-12-31  2022-12-22         2022
#
#       REPORT_MONTH  REPORT_DAY  REPORT_DOY  REPORT_DOW  REPORT_HOUR  ...  \
# 97         January           2           2  Tuesday            15.0  ...
# 98         January           2           2  Tuesday             NaN  ...
# 104        January           2           2  Tuesday            12.0  ...
# 112        January           2           2  Tuesday            12.0  ...
# 114        January           2           2  Tuesday            15.0  ...
# ...            ...         ...         ...         ...          ...  ...
# 40215     December          31         365  Saturday            4.0  ...
# 40217     December          31         365  Saturday           21.0  ...
# 40218     December          31         365  Saturday           21.0  ...
# 40221     December          31         365  Saturday           10.0  ...
# 40223     December          31         365  Saturday           10.0  ...
#
#                                            LOCATION_TYPE PREMISES_TYPE  \
# 97                                      Bar / Restaurant    Commercial
# 98                                    Convenience Stores    Commercial
# 104    Other Commercial / Corporate Places (For Profi...    Commercial
# 112                                     Bar / Restaurant    Commercial
# 114                     Apartment (Rooming House, Condo)     Apartment
# ...                                                  ...           ...
# 40215                         Homeless Shelter / Mission         Other
# 40217                   Apartment (Rooming House, Condo)     Apartment
# 40218                   Apartment (Rooming House, Condo)     Apartment
# 40221  Single Home, House (Attach Garage, Cottage, Mo...         House
# 40223                   Apartment (Rooming House, Condo)     Apartment
#
#        UCR_CODE  UCR_EXT                       OFFENCE     MCI_CATEGORY  \
# 97         1430      100                       Assault          Assault
# 98         2120      220                  B&E W'Intent  Break and Enter
# 104        2120      220                  B&E W'Intent  Break and Enter
# 112        1420      100           Assault With Weapon          Assault
# 114        2130      210                    Theft Over       Theft Over
# ...         ...      ...                           ...              ...
# 40215      1430      100                       Assault          Assault
# 40217      2120      210  Unlawfully In Dwelling-House  Break and Enter
# 40218      1430      100                       Assault          Assault
# 40221      2120      220                  B&E W'Intent  Break and Enter
# 40223      1430      100                       Assault          Assault
#
#       HOOD_158       NEIGHBOURHOOD_158 HOOD_140  \
# 97         130                Milliken      130
# 98         150       Fenside-Parkwoods       45
# 104        122   Birchcliffe-Cliffside      122
# 112        164        Wellington Place       77
# 114        164        Wellington Place       77
# ...        ...                     ...      ...
# 40215      165  Harbourfront-CityPlace       77
# 40217      150       Fenside-Parkwoods       45
# 40218      150       Fenside-Parkwoods       45
# 40221      119        Wexford/Maryvale      119
# 40223      102       Forest Hill North      102
#
#                             NEIGHBOURHOOD_140
# 97                             Milliken (130)
# 98                     Parkwoods-Donalda (45)
# 104               Birchcliffe-Cliffside (122)
# 112    Waterfront Communities-The Island (77)
# 114    Waterfront Communities-The Island (77)
# ...                                       ...
# 40215  Waterfront Communities-The Island (77)
# 40217                  Parkwoods-Donalda (45)
# 40218                  Parkwoods-Donalda (45)
# 40221                  Wexford/Maryvale (119)
# 40223                 Forest Hill North (102)
#
# [37925 rows x 27 columns]

# %%
# Create a new data frame showing just relevant columns
df_simplified = df.loc[:, ['OCC_DATE', 'OCC_HOUR', 'REPORT_DATE', 'REPORT_HOUR']]
df_simplified.head()
# Out:
#      OCC_DATE  OCC_HOUR REPORT_DATE  REPORT_HOUR
# 0  2018-01-01       4.0  2018-01-01          4.0
# 1  2018-01-01      18.0  2018-01-01         18.0
# 2  2018-01-01       2.0  2018-01-01         21.0
# 3  2018-01-01       NaN  2018-01-01         15.0
# 4  2018-01-01      20.0  2018-01-01         20.0

# %%
# Check if all values are in correct format
nan_counts = df_simplified.isna().sum()
print(nan_counts)
# Out:
# OCC_DATE          0
# OCC_HOUR       7528
# REPORT_DATE       0
# REPORT_HOUR    3566
# dtype: int64

# %%
# Clear NaN values, create new data frame
df_cleaned = df_simplified.dropna()
df_cleaned.head()
# Out:
#      OCC_DATE  OCC_HOUR REPORT_DATE  REPORT_HOUR
# 0  2018-01-01       4.0  2018-01-01          4.0
# 1  2018-01-01      18.0  2018-01-01         18.0
# 2  2018-01-01       2.0  2018-01-01         21.0
# 4  2018-01-01      20.0  2018-01-01         20.0
# 5  2018-01-01      20.0  2018-01-01         20.0

# %%
# Create a copy of the main data frame
df_cleaned = df_cleaned.copy()

# Create 2 new columns for occurence and report date showing date + time of offence
df_cleaned['OCC_DATETIME'] = pd.to_datetime(df_cleaned['OCC_DATE'].dt.strftime('%Y-%m-%d') + ' ' + df_cleaned['OCC_HOUR'].astype(str).str.zfill(2) + ':00:00')
df_cleaned['REPORT_DATETIME'] = pd.to_datetime(df_cleaned['REPORT_DATE'].dt.strftime('%Y-%m-%d') + ' ' + df_cleaned['REPORT_HOUR'].astype(str).str.zfill(2) + ':00:00')

# Calculate difference as hour
df_cleaned['HOUR_DIFFERENCE'] = (df_cleaned['REPORT_DATETIME'] - df_cleaned['OCC_DATETIME']).dt.total_seconds() / 3600
df_cleaned.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 5
#       2 df_cleaned = df_cleaned.copy()
#       4 # Create 2 new columns for occurence and report date showing date + time of offence
# ----> 5 df_cleaned['OCC_DATETIME'] = pd.to_datetime(df_cleaned['OCC_DATE'].dt.strftime('%Y-%m-%d') + ' ' + df_cleaned['OCC_HOUR'].astype(str).str.zfill(2) + ':00:00')
#       6 df_cleaned['REPORT_DATETIME'] = pd.to_datetime(df_cleaned['REPORT_DATE'].dt.strftime('%Y-%m-%d') + ' ' + df_cleaned['REPORT_HOUR'].astype(str).str.zfill(2) + ':00:00')
#       8 # Calculate difference as hour
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
#     183 # Replace the property with the accessor object. Inspired by:
#     184 # https://www.pydanny.com/cached-property.html
#     185 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     186 # NDFrame
#     187 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/accessors.py:512, in CombinedDatetimelikeProperties.__new__(cls, data)
#     509 elif is_period_dtype(data.dtype):
#     510     return PeriodProperties(data, orig)
# --> 512 raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
sorted_df = df_cleaned.sort_values(by='HOUR_DIFFERENCE', ascending=False)
sorted_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sorted_df = df_cleaned.sort_values(by='HOUR_DIFFERENCE', ascending=False)
#       2 sorted_df
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:6912, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6908 elif len(by):
#    6909     # len(by) == 1
#    6911     by = by[0]
# -> 6912     k = self._get_label_or_level_values(by, axis=axis)
#    6914     # need to rewrap column in Series to apply key function
#    6915     if key is not None:
#    6916         # error: Incompatible types in assignment (expression has type
#    6917         # "Series", variable has type "ndarray")
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'HOUR_DIFFERENCE'

# %%
# Calculate average difference between when it was occurred and reported
average_hour_difference = df_cleaned['HOUR_DIFFERENCE'].mean()
average_day_difference = average_hour_difference / 24

print(f'Average Difference: {average_hour_difference:.2f} hours or {average_day_difference:.2f} days')
maxhour = df_cleaned['HOUR_DIFFERENCE'].max()
print(f'Maximum value: {maxhour} hours')
# Out:
# Average Difference: 180.22 hours or 7.51 days
# Maximum value: 43584.0 hours

# %%
# Show in statistical visualization

fig1, ax1 = plt.subplots()
ax1.boxplot(df_cleaned['HOUR_DIFFERENCE'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Show in statistical visualization
# ----> 3 fig1, ax1 = plt.subplots()
#       4 ax1.boxplot(df_cleaned['HOUR_DIFFERENCE'])
#       5 plt.show()
#
# NameError: name 'plt' is not defined
