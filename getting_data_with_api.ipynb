# %%
import pandas as pd
import json
import requests
from pprint import pprint

# %%
# Base url for all toronto open data
base_url = "https://ckan0.cf.opendata.inter.prod-toronto.ca"

# Datasets are called "packages". Each package can contain many "resources"
# To retrieve the metadata for this package and its resources, use the package name in this page's URL:
url = base_url + "/api/3/action/package_show"
p = {"id": "major-crime-indicators"}
# get package resources
package = requests.get(url, params = p).json()
# Look at resources and find the one that is datastore_active
for idx, resource in enumerate(package["result"]["resources"]):
    # once we find the datastore_active resource, get the id
    if resource["datastore_active"]:
        resource_id = resource["id"]
# using that id and limit 0, get just the metadata first to find total items
# based on this algorithm:
# https://support.smartbear.com/qacomplete/docs/developer/api/rest/api/reference/paging.html
limit = 0

# build url for retrieve data
url = base_url + "/api/3/action/datastore_search"
# include resource id and limit in url parameters
p = {
    'id': resource_id,
    'limit': limit
}
# get metadata, and pprint it to find total items
metadata = requests.get(url, params = p).json()
pprint(metadata)
# Out:
# {'help': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/help_show?name=datastore_search',
#  'result': {'_links': {'next': '/api/3/action/datastore_search?id=af452875-cfdd-4596-a08a-7b93b65ea4f0&offset=6&limit=2',
#                        'prev': '/api/3/action/datastore_search?id=af452875-cfdd-4596-a08a-7b93b65ea4f0&offset=2&limit=2',
#                        'start': '/api/3/action/datastore_search?id=af452875-cfdd-4596-a08a-7b93b65ea4f0&limit=2'},
#             'fields': [{'id': '_id', 'type': 'int'},
#                        {'id': 'EVENT_UNIQUE_ID',
#                         'info': {'notes': 'Offence Number'},
#                         'type': 'text'},
#                        {'id': 'REPORT_DATE',
#                         'info': {'notes': 'Date Offence was Reported'},
#                         'type': 'date'},
#                        {'id': 'OCC_DATE',
#                         'info': {'notes': 'Date of Offence'},
#                         'type': 'date'},
#                        {'id': 'REPORT_YEAR',
#                         'info': {'notes': 'Year Offence was Reported'},
#                         'type': 'float8'},
#                        {'id': 'REPORT_MONTH',
#                         'info': {'notes': 'Month Offence was Reported'},
#                         'type': 'text'},
#                        {'id': 'REPORT_DAY',
#                         'info': {'notes': 'Day of the Month Offence was '
#                                           'Reported'},
#                         'type': 'float8'},
#                        {'id': 'REPORT_DOY',
#                         'info': {'notes': 'Day of the Year Offence was '
#                                           'Reported'},
#                         'type': 'float8'},
#                        {'id': 'REPORT_DOW',
#                         'info': {'notes': 'Day of the Week Offence was '
#                                           'Reported'},
#                         'type': 'text'},
#                        {'id': 'REPORT_HOUR',
#                         'info': {'notes': 'Hour Offence was Reported'},
#                         'type': 'float8'},
#                        {'id': 'OCC_YEAR',
#                         'info': {'notes': 'Year Offence Occurred'},
#                         'type': 'float8'},
#                        {'id': 'OCC_MONTH',
#                         'info': {'notes': 'Month Offence Occurred'},
#                         'type': 'text'},
#                        {'id': 'OCC_DAY',
#                         'info': {'notes': 'Day of the Month Offence Occurred'},
#                         'type': 'float8'},
#                        {'id': 'OCC_DOY',
#                         'info': {'notes': 'Day of the Year Offence Occurred'},
#                         'type': 'float8'},
#                        {'id': 'OCC_DOW',
#                         'info': {'notes': 'Day of the Week Offence Occurred'},
#                         'type': 'text'},
#                        {'id': 'OCC_HOUR',
#                         'info': {'notes': 'Hour Offence Occurred'},
#                         'type': 'float8'},
#                        {'id': 'DIVISION',
#                         'info': {'notes': 'Police Division where Offence '
#                                           'Occurred'},
#                         'type': 'text'},
#                        {'id': 'LOCATION_TYPE',
#                         'info': {'notes': 'Location Type of Offence'},
#                         'type': 'text'},
#                        {'id': 'PREMISES_TYPE',
#                         'info': {'notes': 'Premises Type of Offence'},
#                         'type': 'text'},
#                        {'id': 'UCR_CODE',
#                         'info': {'notes': 'UCR Code for Offence'},
#                         'type': 'float8'},
#                        {'id': 'UCR_EXT',
#                         'info': {'notes': 'UCR Extension for Offence'},
#                         'type': 'float8'},
#                        {'id': 'OFFENCE',
#                         'info': {'notes': 'Title of Offence'},
#                         'type': 'text'},
#                        {'id': 'MCI_CATEGORY',
#                         'info': {'notes': 'MCI Category of Occurrence'},
#                         'type': 'text'},
#                        {'id': 'HOOD_158',
#                         'info': {'notes': 'Identifier of Neighbourhood using '
#                                           "City of Toronto's new 158 "
#                                           'neighbourhood structure'},
#                         'type': 'text'},
#                        {'id': 'NEIGHBOURHOOD_158',
#                         'info': {'notes': 'Name of Neighbourhood using City of '
#                                           "Toronto's new 158 neighbourhood "
#                                           'structure'},
#                         'type': 'text'},
#                        {'id': 'HOOD_140',
#                         'info': {'notes': 'Identifier of Neighbourhood using '
#                                           "City of Toronto's old 140 "
#                                           'neighbourhood structure'},
#                         'type': 'text'},
#                        {'id': 'NEIGHBOURHOOD_140',
#                         'info': {'notes': 'Name of Neighbourhood using City of '
#                                           "Toronto's old 140 neighbourhood "
#                                           'structure'},
#                         'type': 'text'}],
#             'include_total': True,
#             'limit': 2,
#             'offset': 4,
#             'records': [{'DIVISION': 'D54',
#                          'EVENT_UNIQUE_ID': 'GO-20141261050',
#                          'HOOD_140': '66',
#                          'HOOD_158': '69',
#                          'LOCATION_TYPE': 'Streets, Roads, Highways (Bicycle '
#                                           'Path, Private Road)',
#                          'MCI_CATEGORY': 'Assault',
#                          'NEIGHBOURHOOD_140': 'Danforth (66)',
#                          'NEIGHBOURHOOD_158': 'Blake-Jones',
#                          'OCC_DATE': '2014-01-01',
#                          'OCC_DAY': 1,
#                          'OCC_DOW': 'Wednesday ',
#                          'OCC_DOY': 1,
#                          'OCC_HOUR': 4,
#                          'OCC_MONTH': 'January',
#                          'OCC_YEAR': 2014,
#                          'OFFENCE': 'Assault',
#                          'PREMISES_TYPE': 'Outside',
#                          'REPORT_DATE': '2014-01-01',
#                          'REPORT_DAY': 1,
#                          'REPORT_DOW': 'Wednesday ',
#                          'REPORT_DOY': 1,
#                          'REPORT_HOUR': 4,
#                          'REPORT_MONTH': 'January',
#                          'REPORT_YEAR': 2014,
#                          'UCR_CODE': 1430,
#                          'UCR_EXT': 100,
#                          '_id': 5},
#                         {'DIVISION': 'D52',
#                          'EVENT_UNIQUE_ID': 'GO-20141259344',
#                          'HOOD_140': '77',
#                          'HOOD_158': '164',
#                          'LOCATION_TYPE': 'Bar / Restaurant',
#                          'MCI_CATEGORY': 'Assault',
#                          'NEIGHBOURHOOD_140': 'Waterfront Communities-The '
#                                               'Island (77)',
#                          'NEIGHBOURHOOD_158': 'Wellington Place',
#                          'OCC_DATE': '2014-01-01',
#                          'OCC_DAY': 1,
#                          'OCC_DOW': 'Wednesday ',
#                          'OCC_DOY': 1,
#                          'OCC_HOUR': 2,
#                          'OCC_MONTH': 'January',
#                          'OCC_YEAR': 2014,
#                          'OFFENCE': 'Assault Bodily Harm',
#                          'PREMISES_TYPE': 'Commercial',
#                          'REPORT_DATE': '2014-01-01',
#                          'REPORT_DAY': 1,
#                          'REPORT_DOW': 'Wednesday ',
#                          'REPORT_DOY': 1,
#                          'REPORT_HOUR': 2,
#                          'REPORT_MONTH': 'January',
#                          'REPORT_YEAR': 2014,
#                          'UCR_CODE': 1420,
#                          'UCR_EXT': 110,
#                          '_id': 6}],
#             'records_format': 'objects',
#             'resource_id': 'af452875-cfdd-4596-a08a-7b93b65ea4f0',
#             'total': 323296,
#             'total_estimation_threshold': None,
#             'total_was_estimated': False},
#  'success': True}

# %%
# within the results,
# 'fields' contains data of what each column means
# and the actual data is in 'records' as a list of dictionaries

# get total items from metadata
total_items = metadata['result']['total']
total_items
# Out:
# 323296

# %%
# From documentation, we know the max limit is 32000
# so we set, limit to that
limit = 32000

# offset will start at 0 and increase by 32000 each loop time
offset = 0

# While offset is under total_items
while offset < total_items:
    

    # To finish loop section, increase offset by limit
    offset += limit

# Final request, does not use limit, to get all the rest of the data


# Loop using offset and limit
    # Merge datasets
# Write to csv

# %%
resource_search_data['total']
# Out:
# 38458

# %%
# put data into a pandas dataframe
df = pd.DataFrame(resource_search_data['records'])
len(df)
# Out:
# 32000

# %%
df
# Out:
#           _id EVENT_UNIQUE_ID REPORT_DATE    OCC_DATE  REPORT_YEAR  \
# 0      165888  GO-20182077483  2018-11-10  2018-11-10         2018
# 1      135146    GO-201878326  2018-01-13  2018-01-13         2018
# 2      136561   GO-2018169363  2018-01-27  2018-01-27         2018
# 3      134252    GO-201813328  2018-01-03  2018-01-03         2018
# 4      136429   GO-2018159453  2018-01-26  2018-01-26         2018
# ...       ...             ...         ...         ...          ...
# 31995  144134   GO-2018672630  2018-04-15  2018-04-15         2018
# 31996  144135   GO-2018672379  2018-04-15  2018-04-15         2018
# 31997  144136   GO-2018672565  2018-04-15  2018-04-15         2018
# 31998  144137   GO-2018672544  2018-04-15  2018-04-15         2018
# 31999  144138   GO-2018672048  2018-04-15  2018-04-15         2018
#
#       REPORT_MONTH  REPORT_DAY  REPORT_DOY  REPORT_DOW  REPORT_HOUR  ...  \
# 0         November          10         314  Saturday           23.0  ...
# 1          January          13          13  Saturday           13.0  ...
# 2          January          27          27  Saturday           16.0  ...
# 3          January           3           3  Wednesday           9.0  ...
# 4          January          26          26  Friday              1.0  ...
# ...            ...         ...         ...         ...          ...  ...
# 31995        April          15         105  Sunday             11.0  ...
# 31996        April          15         105  Sunday              9.0  ...
# 31997        April          15         105  Sunday             11.0  ...
# 31998        April          15         105  Sunday             12.0  ...
# 31999        April          15         105  Sunday              8.0  ...
#
#        PREMISES_TYPE UCR_CODE  UCR_EXT            OFFENCE MCI_CATEGORY  \
# 0              House     1430      100            Assault      Assault
# 1            Transit     1430      100            Assault      Assault
# 2            Transit     1430      100            Assault      Assault
# 3            Transit     1430      100            Assault      Assault
# 4         Commercial     1430      100            Assault      Assault
# ...              ...      ...      ...                ...          ...
# 31995          House     1430      100            Assault      Assault
# 31996     Commercial     1430      100            Assault      Assault
# 31997      Apartment     1430      100            Assault      Assault
# 31998     Commercial     1430      100            Assault      Assault
# 31999      Apartment     1610      200  Robbery - Mugging      Robbery
#
#        HOOD_158                  NEIGHBOURHOOD_158 HOOD_140  \
# 0           124                       Kennedy Park      124
# 1            95                              Annex       95
# 2           NSA                                NSA      NSA
# 3            95                              Annex       95
# 4           107                    Oakwood Village      107
# ...         ...                                ...      ...
# 31995       111                  Rockcliffe-Smythe      111
# 31996       NSA                                NSA      NSA
# 31997       162                    West Queen West       82
# 31998       167                   Church-Wellesley       75
# 31999         2  Mount Olive-Silverstone-Jamestown        2
#
#                            NEIGHBOURHOOD_140      rank
# 0                         Kennedy Park (124)  0.079652
# 1                                 Annex (95)  0.079652
# 2                                        NSA  0.079652
# 3                                 Annex (95)  0.079652
# 4                      Oakwood Village (107)  0.079652
# ...                                      ...       ...
# 31995                Rockcliffe-Smythe (111)  0.079652
# 31996                                    NSA  0.079652
# 31997                           Niagara (82)  0.079652
# 31998             Church-Yonge Corridor (75)  0.079652
# 31999  Mount Olive-Silverstone-Jamestown (2)  0.079652
#
# [32000 rows x 28 columns]
